# %%
import pandas as pd

df = pd.read_csv('03-实训数据/Training_Userupdate.csv',sep='\t',encoding='gb18030')

# %%
import pandas as pd
csv_data = pd.read_csv('03-实训数据/Training_Master.csv', sep = ',', encoding = 'gb18030')

csv_data
# Out:
#          Idx  UserInfo_1  UserInfo_2  UserInfo_3  UserInfo_4  WeblogInfo_1  \
# 0      10001         1.0          深圳         4.0          深圳           NaN
# 1      10002         1.0          温州         4.0          温州           NaN
# 2      10003         1.0          宜昌         3.0          宜昌           NaN
# 3      10006         4.0          南平         1.0          南平           NaN
# 4      10007         5.0          辽阳         1.0          辽阳           NaN
# 5      10008         1.0          吴忠         5.0          银川           NaN
# 6      10011         1.0          绵阳         3.0          赤峰           NaN
# 7      10015         4.0          东莞         5.0          东莞           NaN
# 8      10019         1.0          赤峰         6.0          赤峰           NaN
# 9      10021         3.0          武汉         5.0          鄂州           NaN
# 10     10022         5.0          武汉         5.0          武汉           NaN
# ...
